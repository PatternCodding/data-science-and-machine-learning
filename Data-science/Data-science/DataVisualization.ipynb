# %% [markdown]
# # Introduction to matplotlip Lecture .
#
# ## What is matplolip?:
# * Matplolip is the most popular plotting library for python
# * It gives you control over every aspect of a figure
# * It was designed to have a similar feel to MatLab's graphical plotting.

# %% [markdown]
# # Requirements:
# * install matplolib either with conda or pip in your terminal

# %% [markdown]
# # Official wensite!
# * https://matplotlib.org/2.0.2/index.html is the official website, from there to the gallery you'll see the capabilities of matplolib

# %% [markdown]
# # How we can begin to use matplolib with python!

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # if you are using jupyter notebook you will have to type the code command below:
# * which alloww you to see the plot you created inside the notebook

# %%
# %matplotlib inline

# %% [markdown]
# # else if you're not using jupyter notebook, you'll hav to use the following command to see your plot.
#
# * plt.show()

# %% [markdown]
# # Example using two Numpy arrays

# %%
import numpy as np
x= np.linspace(0,5,11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %% [markdown]
# # there are two ways of plotting using matpli, and they're:
#
# 1. Functional method()
# 2. Object Orinted method()

# %% [markdown]
# # the Functional Method

# %%
plt.plot(x,y)
# plt.show(x,y) # does not disply the plotting menu

# %% [markdown]
# # adding colors

# %%
plt.plot(x,y,color='red')

# %% [markdown]
# # adding X-Label and Y-Lebel and Title

# %%
plt.plot(x,y)
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.title('My first Graph', color='red')
# Out:
# Text(0.5, 1.0, 'My first Graph')

# %% [markdown]
# # creating multi-plot on thesame Canva. this requires three arguments, 1st is for the no of rows, 2nd for no. of colums, 3rd is the plot no.

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')

plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %% [markdown]
# # 2. The Object Oriented Program Method: this is the best way of plotting grapghs with matplotib, although the above is more simple. the main idea of using this method is to create a figure objects, and is of two methods:

# %% [markdown]
# # FIRST METHOD, USING FIG()

# %%
fig = plt.figure()


axes = fig.add_axes([0.1,0.1,0.8,0.8]) #len and widht of the axes

axes.plot(x,y)

axes.set_xlabel('X Label')
axes.set_ylabel('Y Label')
axes.set_title('My graph using OO method',color='green')
# Out:
# Text(0.5, 1.0, 'My graph using OO method')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3])

# %% [markdown]
# # trying to get the 2nd axes to the buttom of the 1st

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes2 = fig.add_axes([0.5, 0.15, 0.4, 0.3])

# %% [markdown]
# #  plotting the original graph axes

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3])

axes1.plot(x,y)
axes2.plot(y,x)

axes1.set_title("BIGGER PLOT")
axes2.set_title("SMALLER PLOT")
# Out:
# Text(0.5, 1.0, 'SMALLER PLOT')

# %% [markdown]
# # SECTION TWO: OBJECT ORIENTED PROGRAMMING.

# %% [markdown]
# ### USING SUBPLOTS() which is the second method of OO

# %%
fig,axes= plt.subplots()
axes.plot(x,y)

# %% [markdown]
# # where subplotes() defers is you can specify the number of rown and colunms you want

# %%
fig,axes= plt.subplots(nrows=3,ncols=3)

# %% [markdown]
# # dealing with overlapping

# %%
fig,axes= plt.subplots(nrows=3,ncols=3)
plt.tight_layout()

# %% [markdown]
# # lets continue working with 1x2 grapgh

# %%
fig,axes= plt.subplots(nrows=1,ncols=2)

# %% [markdown]
# # the above code is just same as typing fig =  axes, and the axes is
# # just the list of the items! meaning we can iterate thriugh it.

# %%
fig,axes= plt.subplots(nrows=1,ncols=2)

for current_ax in axes:
        current_ax.plot(x,y)

# %% [markdown]
# # since we can iterate this objects that means we can as well index it

# %%
fig,axes= plt.subplots(nrows=1,ncols=2)

axes[0].plot(x,y)
axes[1].plot(y,x)

# adding titles

axes[0].set_title("First plot")
axes[1].set_title("Second plot")
# Out:
# Text(0.5, 1.0, 'Second plot')

# %% [markdown]
# # FIGURE SIZE AND DPI:
# * DPI simply means dot per inch.
# * Matplolib allows you to take full control of how you would like your on=bjest to look like

# %%
fig = plt.figure(figsize=(9,2)) #,dpi=100)
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %% [markdown]
# # Using subplots() method to perform same action

# %%
fig,axes = plt.subplots(figsize=(9,2)) #,dpi=100)
axes.plot(x,y)

# %% [markdown]
# # Adding some rows and columns

# %%
fig,axes = plt.subplots(nrows=2,ncols=1, figsize=(8,4)) #,dpi=100)
axes[0].plot(x,y)
axes[1].plot(y,x)

plt.tight_layout()

# %% [markdown]
# # HOW TO SAVE A FIGURE AND DPI

# %%
fig

# %%
fig.savefig('my_pictures//my_pictures.png',dpi=200)

# %% [markdown]
# # lets set the X and Y label

# %%
fig = plt.figure() #,dpi=100)
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

ax.set_title('Patterson',color='red')
ax.set_ylabel('Y axis')
ax.set_xlabel('X axis')
# Out:
# Text(0.5, 0, 'X axis')

# %% [markdown]
# # lets talk about Legends!: with legends you can be able to use lael tags to actually specify or clearify what plot is what what plot
#
#
#
# ## There are two ways of adding a legend.
# 1. using ax.legend() at the bottom of your code
# 2. adding string labels to the plot parameters

# %%
fig = plt.figure() #,dpi=100)
ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2, label='X Squared')
ax.plot(x,x**3, label='X Cubed')

ax.legend(loc=10)
# there are many ways of adding the location.
ax.legend(loc=(0.1,0.1))
ax.legend(loc=1) etc
# Out:
#   File "<ipython-input-28-47228375160e>", line 9
#     ax.legend(loc=1) etc
#                      ^
# SyntaxError: invalid syntax

# %% [markdown]
# # SECTION THREE:
# ## outlines:
# * setting colors
# * line width and line style
# * then customize your options on how your customize should actually looks like

# %% [markdown]
# # setting colors with matplolib

# %%
fig = plt.figure() 
ax = fig.add_axes([0,0,1,1])

# can actually take a hex color
ax.plot(x,y,color='#FF8C00')

# %% [markdown]
# # line width and line style

# %%
fig = plt.figure() 
ax = fig.add_axes([0,0,1,1])


# ax.plot(x,y,color='purple', linewidth=10)

# adding an aplha argument which llows u control how transparent you want the line to be
# ax.plot(x,y,color='purple', linewidth=3, alpha=0.5)
# shorthand 
# ax.plot(x,y,color='purple', lw=3, alpha=0.5)

# linestyle: this can take some linestyles like dashed, dotted, star etc

ax.plot(x,y,color='purple', lw=3, alpha=0.5, ls='-.') #--, :, steps,

# %% [markdown]
# # markers: this can be used when we have a few data points.
#
# ### just like trying to see where x are in the graph which the len is 11 points

# %%
fig = plt.figure() 
ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color='red', lw=3, ls='-', marker='o', markersize=10,
       markerfacecolor='yellow',markeredgewidth=5,markeredgecolor='green') # for markertypes +, o, *, 1,

# %% [markdown]
# # you can visit online for more customizations

# %% [markdown]
# # Control over axis and plot range

# %% [markdown]
# # setting the X and Y limit

# %%
fig = plt.figure() 
ax = fig.add_axes([0,0,1,1])


ax.plot(x,y,color='green', lw=2 , ls='--')

# plot btw zero and one on the X axis
ax.set_xlim([0,1]) #1st arg = lower 2nd = upper bam
ax.set_ylim([0,2])
# Out:
# (0.0, 2.0)

# %% [markdown]
# # special Plot Types:
#
# #### there are allots of special plot types you can creat, such as barplots, histograms, scatter plots, and much more. Most of these types of plots we will actually create using seabon, a statistical plotting library for python. But here are a few examples of these types plots:

# %% [markdown]
# # fore more examples visit:
# * http://www.matplotlib.org - The project web pages for matplolib
# * https://github.com/matplotlib/matplotlib - the source code for matplotlib
# * http://matplotlib.org/gallery.html - A large gallery showcaseing various types of plots
# * http://www.loria.fr/~rougier/teaching/matplotlib - A good matplotlib tutorial
# * http://scipy-lecture.github.io/matplotlib.html - Another matplotlib reference

# %%
import matplotlib.pyplot as plt
import numpy as np

# plt.style.use('_mpl-gallery')

# make data
x = np.linspace(0, 10, 100)
y = 4 + 2 * np.sin(2 * x)

# plot
fig, ax = plt.subplots()

ax.plot(x, y, linewidth=2.0)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %%
"""
===================
Styling with cycler
===================

Demo of custom property-cycle settings to control colors and other style
properties for multi-line plots.

This example demonstrates two different APIs:

    1. Setting the default rc parameter specifying the property cycle.
       This affects all subsequent axes (but not axes already created).
    2. Setting the property cycle for a single pair of axes.
"""
from cycler import cycler
import numpy as np
import matplotlib.pyplot as plt


x = np.linspace(0, 2 * np.pi)
offsets = np.linspace(0, 2*np.pi, 4, endpoint=False)
# Create array with shifted-sine curve along each column
yy = np.transpose([np.sin(x + phi) for phi in offsets])

# 1. Setting prop cycle on default rc parameter
plt.rc('lines', linewidth=4)
plt.rc('axes', prop_cycle=(cycler('color', ['r', 'g', 'b', 'y']) +
                           cycler('linestyle', ['-', '--', ':', '-.'])))
fig, (ax0, ax1) = plt.subplots(nrows=2)
ax0.plot(yy)
ax0.set_title('Set default color cycle to rgby')

# 2. Define prop cycle for single set of axes
ax1.set_prop_cycle(cycler('color', ['c', 'm', 'y', 'k']) +
                   cycler('lw', [1, 2, 3, 4]))
ax1.plot(yy)
ax1.set_title('Set axes color cycle to cmyk')

# Tweak spacing between subplots to prevent labels from overlapping
fig.subplots_adjust(hspace=0.3)

# %%
from random import sample
data = sample(range(1, 1000), 100)
plt.hist(data)
# Out:
# (array([12., 10., 12., 10., 14., 13.,  6.,  8.,  9.,  6.]),
#  array([  4. , 103.2, 202.4, 301.6, 400.8, 500. , 599.2, 698.4, 797.6,
#         896.8, 996. ]),
#  <BarContainer object of 10 artists>)
