# %% [markdown]
# # INTRODUCTION TO SEABORN.

# %% [markdown]
# * Seaborn is a statistical plotting library.
# * It has beautiful defaults styles
# * It also designed to work very well with Pandas dataFrame objects

# %% [markdown]
# # REGUIEMENTS:
# * You'll need to install it with either pip or conda in your terminal or command line with
# * conda install Seaborn or
# * pip install Seaborn

# %% [markdown]
# # OFFICIAL WEBITE:
# * https://seaborn.pydata.org/index.html

# %% [markdown]
# # DISRIUTION PLOT:
# * In this lecture we are going to be dealing with differen ways of creating which allows us to visualize data of a set.

# %%
import seaborn as sns

# %% [markdown]
# # for data visualization inside the notebook

# %%
# %matplotlib inline

# %% [markdown]
# # built-in data of seaborn.

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # our first plot type which is dist plot:
# ### this allows us to to plot univerial of distribution, ie one variable

# %%
# lets see how the total ill is distributed.

sns.displot(tips['total_bill'],kde=True)

# %% [markdown]
# # kde simply means kernal density extimation plot()

# %% [markdown]
# # getting more information about the bills, by adding more values

# %%
sns.displot(tips['total_bill'],kde=False, bins=30)

# %% [markdown]
# # JOINT PLOT:
# ### This allows us to basicaly match-up to distplot by various data. joint plot allows us to combine two diff. variables.
#
# ### let's plot the distribution of total_bill vs tips size

# %%
sns.jointplot(x='total_bill', y='tip', data=tips)

# %% [markdown]
# # explanation: the sns is the acronym of seabon, distplot is the method we are using. x and yare  been assigned to the viables the are to be compared to. then pass in your data set which we give as tip

# %% [markdown]
# # joint method allows us to visualize what is actually going on insde the plot, using a function called *kind*. by default this plot is *scattered* you can pass in your own argument, such as hexagon, which allows us to see more on the distribution. another one is regration

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='hex')

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='reg')

# %% [markdown]
# # when we get to machine learning we'll talk more about regration.

# %% [markdown]
# # another one will allow us to have two dymension of kde, ie the kde function

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='kde')

# %% [markdown]
# # all the above plotting always shows where the match-up does most.

# %% [markdown]
# # we are going to be using scatter which allows us to understand more of the plot.
#
#
# # let's talk about pairplot: this allows us to plot pair-wise relationship across the entire dataFramea.
#
# # note the larger your dataFrame the longer the paiplot takes

# %%
sns.pairplot(tips)

# %% [markdown]
# # paiplot is a very goood plotting method to visualize a data.
#
# # adding some parameters like *hue* which allows you to specify a particular data variable for color comparism.
#
# # another one is the *palette* which allows us to color the variable with some specifical colors

# %%
sns.pairplot(tips, hue='sex')

# %%
sns.pairplot(tips, hue='sex',palette='coolwarm')

# %% [markdown]
# # RUGPLOT(): we'll use this to fully explain kde is .
#
# # this draws a mark-line below, on the univerial distributions

# %%
sns.rugplot(tips['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %% [markdown]
# # difference btw rugplot and displot or histogram is that the rugplot has bins and counts how many dashes that are found on the bins while the histogram shows it as number upward. mening from 10-11 there's about 45 dashes

# %%
sns.displot(tips['total_bill'],kde=False)

# %% [markdown]
# # building and kde Kernel Density Estimation plot. is a non-parameter way to estimate the probablity dendsity function of random variable.
# ### this kde explains the Normal or Gaussian distribution: in probability theory it's very common continiouse probability distribution.
# #### Normal distribution are important in statistics are often used in the natural and social sciences to represent real-valued random variables whose distribution is met.
#
# ### just like determining how everyone did the exam, or determining peoples age.

# %%
#  don't worry about understanding this code! just for diagram explanations.

import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# create dataset
dataset = np.random.randn(25)

# creating another ruplot
sns.rugplot(dataset);

# set up the x-axis for the plot
x_min = dataset.min() - 2
x_max = dataset.max() + 2

# 100 equally spaced points from x-min to x_max
x_axis = np.linspace(x_min, x_max, 100)

# set up the bandwidth, for info on this:
url = 'http://en.wikipedia.org/wiki/kernel_density_estimaton#Practical_estimation_of_the_bandwidth'

bandwidth = ((4*dataset.std()**5)/(3*len(dataset))) ** .2

# create an empty kernel list
kernel_list = []

# plot each basic function
for data_point in dataset:
    
    
    #create a kernel for each point and append to list
    kernel = stats.norm(data_point, bandwidth).pdf(x_axis)
    kernel_list.append(kernel)
    
    #scale for plotting
    kernel = kernel / kernel.max()
    kernel = kernel * .4
    plt.plot(x_axis, kernel, color = 'grey', alpha = 0.5)
    
plt.ylim(0,1)
# Out:
# (0.0, 1.0)

# %% [markdown]
# # let's sum them all up to get the normal distribution basis function

# %%
# To get the kde plot we can sum these basis functions.

# plotting the sum of the basis function
sum_of_kde = np.sum(kernel_list, axis=0)

# plot figure
fig = plt.plot(x_axis, sum_of_kde, color='green')

# add the initial rugplot
sns.rugplot(dataset, c = 'red')

# get rid of y-tick marks
plt.yticks([])

# set title
plt.suptitle("Sum of the Basis Funtions")
# Out:
# Text(0.5, 0.98, 'Sum of the Basis Funtions')

# %% [markdown]
# # CATEGORICAL PLOTS:
# ### we are mainly going to concerned on seeing the distribution of the variales like sex or gender, smoker, day, time and the size in reference to one of the numerical columns

# %%
import numpy as np

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # the most common categorical plot is the:
#
# # BAR PLOT(): this allows you to  generate the categorical data based of some functions, which by default the mean(). you can take this as a visualization of group by action

# %%
sns.barplot(x= 'sex', y = 'total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# # adding the estimator argument, to see how the values are been counted, setting the estimator as standard deviation (std)

# %%
sns.barplot(x= 'sex', y = 'total_bill', data=tips, estimator=np.std)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# # you can pass in your own std argument, just for visualization for some mechanism

# %% [markdown]
# # let's talk about a Count plot().
# ## this is essentially thesam as the barplot in seaborn. except the estimator is explicively counting the number of occurences. bcos of that, we can only set the x value and the data

# %%
sns.countplot(x='sex', data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# # boxplot  which is used to show the distribution of categorical data, a box plot is also known as a BOX, which and comaparism of data

# %%
sns.boxplot(x='day', y='total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # adding some hue in the boxplot(), which would allow us split up this boxplot even further by another categorical color.
#
#
# # boxplot is very good specification, indicating if someone according to the data provided is a smoker

# %%
sns.boxplot(x='day', y='total_bill', data=tips, hue='smoker')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Let's talk about violence plot(). this plays a similar role like boxplot(), and shows the distribution of some data accross the sections

# %%
sns.violinplot(x='day', y='total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # comparing the boxplot and the violinsplot, you'll see it's similarities.                                                                              the violinplot unlike the boxplot allows us to plot all of the componets across the actual data points, and it's essentially showing the kde of the underline distribution. and this is essentially the distribution on the side if it's been split up. and it gives more details about data where about

# %%
sns.boxplot(x='day', y='total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # and the violinplot can as well accept hue=''

# %%
sns.violinplot(x='day', y='total_bill', data=tips, hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # violinplot can be splitted instead of it to be in conjuct, do display more information at once

# %%
sns.violinplot(x='day', y='total_bill', data=tips, hue='sex', split=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # more on advanced data visualizations on this kind of categorical data, we are going to start with:
#
# # Stripplot: this is the simplest which draws a scatter plot where one variable is categorical

# %%
sns.stripplot(x='day', y='total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # one problem about stripplot is that you can't tell which data is  ontop of each other. what you can do is to add another argument called jitter which will add a little bit of random noil to seperate some of this stacked poits

# %%
sns.stripplot(x='day', y='total_bill', data=tips, jitter=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # it can as well welcome hue and split argument. but under this method split has been renamed to dodge

# %%
sns.stripplot(x='day', y='total_bill', data=tips, hue='sex', dodge=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # many people combine the idea of stripplot vs violinplot and create what's called *swarmplot*
#
# # swarmplot is similar to stripplot just that there poins does not overlap like striplot, and it give a better representation of the disrtibution values. it's kind of combibing the scatterplot, stripplot with a violinplot

# %%
sns.swarmplot(x='day', y='total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # swarmplot is not good to be used while working with a very large amount of data, else it might stcked to each other and interpretation might be difficult. just stay away from it.
#
# # but if you like it and would like to combine it with the violinplot

# %%
sns.violinplot(x='day', y='total_bill', data=tips)
sns.swarmplot(x='day', y='total_bill', data=tips,color='black')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # pls there's allots of hidden information here so you need to be very extreemly careful. it's not good for presentation but for exploitary of data analysis. you can rather e using boxplot

# %% [markdown]
# # the last plot we'll be talking about is the factorplot, this is essentially more general than all those plots, the diffrence there is it takes a kind argument after can take other arguments like others. which describes the factorplot(). *note* the factorplot has been renamed to catplot

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind='bar')

# %% [markdown]
# # can take other plots as a kind result

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind='violin')

# %% [markdown]
# # well i prefare calling the particular plot am plotting.
#
#
# # this is all for now about categorical plotting, be careful while handling the power to avoid errors and know where, whom and what you're presenting before choosing any kind of plotting method

# %% [markdown]
# # matrix plotting.
#
# ## we'll be using seaborn in this lecture as well

# %%
# tips = sns.load_dataset('tips')
# flights = sns.load_dataset('flights')
# tips.head()
